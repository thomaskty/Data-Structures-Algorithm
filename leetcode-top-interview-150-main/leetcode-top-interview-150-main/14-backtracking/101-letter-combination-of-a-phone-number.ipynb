# %% [markdown]
# # Question 99 - LC 17. Letter Combinations of a Phone Number
#
# Given a string containing digits from `2-9` inclusive, return all possible letter combinations that the number could represent. Return the answer in **any order**.
#
# A mapping of digits to letters (just like on the telephone buttons) is given below. Note that 1 does not map to any letters.
#
# ## Example 1:
#
#     Input: digits = "23"
#     Output: ["ad","ae","af","bd","be","bf","cd","ce","cf"]
#
# ## Example 2:
#
#     Input: digits = ""
#     Output: []
#
# ## Example 3:
#
#     Input: digits = "2"
#     Output: ["a","b","c"]
#
# ## Constraints:
#
# - `0 <= digits.length <= 4`
# - `digits[i]` is a digit in the range `['2', '9']`.

# %%
class Solution:
    def letterCombinations(self, digits: str) -> list[str]:
        if not digits:
            return []

        digit_to_letters = {
            "2": "abc",
            "3": "def",
            "4": "ghi",
            "5": "jkl",
            "6": "mno",
            "7": "pqrs",
            "8": "tuv",
            "9": "wxyz",
        }

        combinations = []

        def backtrack(index: int, path: list[str]):
            if index == len(digits):
                combinations.append("".join(path))
                return

            letters = digit_to_letters[digits[index]]
            for letter in letters:
                path.append(letter)
                backtrack(index + 1, path)
                path.pop()

        backtrack(0, [])

        return combinations

# %%
s = Solution()

# Test Case 1: Normal case with two digits
input_digits = "23"
expected_output = ["ad", "ae", "af", "bd", "be", "bf", "cd", "ce", "cf"]
result = s.letterCombinations(input_digits)
print("Test Case 1 - Expected:", expected_output)
print("Test Case 1 - Result:", result)
print("Test Case 1 - Pass:", sorted(result) == sorted(expected_output))

# Test Case 2: Empty input string
input_digits = ""
expected_output = []
result = s.letterCombinations(input_digits)
print("Test Case 2 - Expected:", expected_output)
print("Test Case 2 - Result:", result)
print("Test Case 2 - Pass:", result == expected_output)

# Test Case 3: Single digit
input_digits = "2"
expected_output = ["a", "b", "c"]
result = s.letterCombinations(input_digits)
print("Test Case 3 - Expected:", expected_output)
print("Test Case 3 - Result:", result)
print("Test Case 3 - Pass:", sorted(result) == sorted(expected_output))

# Test Case 4: All unique digits
input_digits = "279"
expected_output = ["apw", "apx", "apy", "apz", "aqw", "aqx", "aqy", "aqz", "arw", "arx", "ary", "arz", "asw", "asx", "asy", "asz",
                   "bpw", "bpx", "bpy", "bpz", "bqw", "bqx", "bqy", "bqz", "brw", "brx", "bry", "brz", "bsw", "bsx", "bsy", "bsz",
                   "cpw", "cpx", "cpy", "cpz", "cqw", "cqx", "cqy", "cqz", "crw", "crx", "cry", "crz", "csw", "csx", "csy", "csz"]
result = s.letterCombinations(input_digits)
print("Test Case 4 - Expected:", expected_output)
print("Test Case 4 - Result:", result)
print("Test Case 4 - Pass:", sorted(result) == sorted(expected_output))

# Test Case 5: Four digits
input_digits = "2345"
expected_output = ['adgj', 'adgk', 'adgl', 'adhj', 'adhk', 'adhl', 'adij', 'adik', 'adil',
                   'aegj', 'aegk', 'aegl', 'aehj', 'aehk', 'aehl', 'aeij', 'aeik', 'aeil',
                   'afgj', 'afgk', 'afgl', 'afhj', 'afhk', 'afhl', 'afij', 'afik', 'afil',
                   'bdgj', 'bdgk', 'bdgl', 'bdhj', 'bdhk', 'bdhl', 'bdij', 'bdik', 'bdil',
                   'begj', 'begk', 'begl', 'behj', 'behk', 'behl', 'beij', 'beik', 'beil',
                   'bfgj', 'bfgk', 'bfgl', 'bfhj', 'bfhk', 'bfhl', 'bfij', 'bfik', 'bfil',
                   'cdgj', 'cdgk', 'cdgl', 'cdhj', 'cdhk', 'cdhl', 'cdij', 'cdik', 'cdil',
                   'cegj', 'cegk', 'cegl', 'cehj', 'cehk', 'cehl', 'ceij', 'ceik', 'ceil',
                   'cfgj', 'cfgk', 'cfgl', 'cfhj', 'cfhk', 'cfhl', 'cfij', 'cfik', 'cfil']
result = s.letterCombinations(input_digits)
print("Test Case 5 - Expected:", expected_output)
print("Test Case 5 - Result:", result)
print("Test Case 5 - Pass:", sorted(result) == sorted(expected_output))
# Out:
# Test Case 1 - Expected: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Test Case 1 - Result: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Test Case 1 - Pass: True
# Test Case 2 - Expected: []
# Test Case 2 - Result: []
# Test Case 2 - Pass: True
# Test Case 3 - Expected: ['a', 'b', 'c']
# Test Case 3 - Result: ['a', 'b', 'c']
# Test Case 3 - Pass: True
# Test Case 4 - Expected: ['apw', 'apx', 'apy', 'apz', 'aqw', 'aqx', 'aqy', 'aqz', 'arw', 'arx', 'ary', 'arz', 'asw', 'asx', 'asy', 'asz', 'bpw', 'bpx', 'bpy', 'bpz', 'bqw', 'bqx', 'bqy', 'bqz', 'brw', 'brx', 'bry', 'brz', 'bsw', 'bsx', 'bsy', 'bsz', 'cpw', 'cpx', 'cpy', 'cpz', 'cqw', 'cqx', 'cqy', 'cqz', 'crw', 'crx', 'cry', 'crz', 'csw', 'csx', 'csy', 'csz']
# Test Case 4 - Result: ['apw', 'apx', 'apy', 'apz', 'aqw', 'aqx', 'aqy', 'aqz', 'arw', 'arx', 'ary', 'arz', 'asw', 'asx', 'asy', 'asz', 'bpw', 'bpx', 'bpy', 'bpz', 'bqw', 'bqx', 'bqy', 'bqz', 'brw', 'brx', 'bry', 'brz', 'bsw', 'bsx', 'bsy', 'bsz', 'cpw', 'cpx', 'cpy', 'cpz', 'cqw', 'cqx', 'cqy', 'cqz', 'crw', 'crx', 'cry', 'crz', 'csw', 'csx', 'csy', 'csz']
# Test Case 4 - Pass: True
# Test Case 5 - Expected: ['adgj', 'adgk', 'adgl', 'adhj', 'adhk', 'adhl', 'adij', 'adik', 'adil', 'aegj', 'aegk', 'aegl', 'aehj', 'aehk', 'aehl', 'aeij', 'aeik', 'aeil', 'afgj', 'afgk', 'afgl', 'afhj', 'afhk', 'afhl', 'afij', 'afik', 'afil', 'bdgj', 'bdgk', 'bdgl', 'bdhj', 'bdhk', 'bdhl', 'bdij', 'bdik', 'bdil', 'begj', 'begk', 'begl', 'behj', 'behk', 'behl', 'beij', 'beik', 'beil', 'bfgj', 'bfgk', 'bfgl', 'bfhj', 'bfhk', 'bfhl', 'bfij', 'bfik', 'bfil', 'cdgj', 'cdgk', 'cdgl', 'cdhj', 'cdhk', 'cdhl', 'cdij', 'cdik', 'cdil', 'cegj', 'cegk', 'cegl', 'cehj', 'cehk', 'cehl', 'ceij', 'ceik', 'ceil', 'cfgj', 'cfgk', 'cfgl', 'cfhj', 'cfhk', 'cfhl', 'cfij', 'cfik', 'cfil']
# Test Case 5 - Result: ['adgj', 'adgk', 'adgl', 'adhj', 'adhk', 'adhl', 'adij', 'adik', 'adil', 'aegj', 'aegk', 'aegl', 'aehj', 'aehk', 'aehl', 'aeij', 'aeik', 'aeil', 'afgj', 'afgk', 'afgl', 'afhj', 'afhk', 'afhl', 'afij', 'afik', 'afil', 'bdgj', 'bdgk', 'bdgl', 'bdhj', 'bdhk', 'bdhl', 'bdij', 'bdik', 'bdil', 'begj', 'begk', 'begl', 'behj', 'behk', 'behl', 'beij', 'beik', 'beil', 'bfgj', 'bfgk', 'bfgl', 'bfhj', 'bfhk', 'bfhl', 'bfij', 'bfik', 'bfil', 'cdgj', 'cdgk', 'cdgl', 'cdhj', 'cdhk', 'cdhl', 'cdij', 'cdik', 'cdil', 'cegj', 'cegk', 'cegl', 'cehj', 'cehk', 'cehl', 'ceij', 'ceik', 'ceil', 'cfgj', 'cfgk', 'cfgl', 'cfhj', 'cfhk', 'cfhl', 'cfij', 'cfik', 'cfil']
# Test Case 5 - Pass: True
